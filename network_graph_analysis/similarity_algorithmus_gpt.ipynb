# %% [markdown]
# ## Similarity Algorithmus
# Diese Notebook demonstriert das Ausprobieren der Similarity Algorithmen auf Finanzdaten

# %% [markdown]
# ### Verbindung zu Neo4j

# %%
from neo4j import GraphDatabase

uri = "bolt://localhost:7687" 
username = "neo4j"
password = ""

driver = GraphDatabase.driver(uri, auth=(username, password))

# %% [markdown]
# ### Ausführen Jaccard Ähnlichkeitsalgoritmus

# %%
from neo4j import GraphDatabase

def get_jaccard_similarity(tx):
    query = """
    MATCH (p1:Person)-[:TRANSACTION]->(other)
    WITH p1, collect(id(other)) AS p1Others
    MATCH (p2:Person)-[:TRANSACTION]->(other)
    WHERE id(p1) < id(p2)  // This ensures each pair is only compared once
    WITH p1, p1Others, p2, collect(id(other)) AS p2Others
    RETURN p1.name AS person1, p2.name AS person2, gds.similarity.jaccard(p1Others, p2Others) AS similarity
    ORDER BY similarity DESC, person1, person2
    """
    result = tx.run(query)
    return [{"person1": record["person1"], "person2": record["person2"], "similarity": record["similarity"]} for record in result]


# Example usage:
with driver.session() as session:
    similarities = session.execute_read(get_jaccard_similarity)

import pandas as pd
df_similarities = pd.DataFrame(similarities)
print(df_similarities)
# Zähle die Anzahl der Ähnlichkeiten, die gleich 1 sind
count_1 = df_similarities[df_similarities['similarity'] == 1.0].shape[0]

# Zähle die Anzahl der Ähnlichkeiten, die nicht gleich 1 sind
count_not_1 = df_similarities[df_similarities['similarity'] != 1.0].shape[0]
print("Anzahl der Ähnlichkeiten mit Wert 1:", count_1)
print("Anzahl der Ähnlichkeiten mit Wert ungleich 1:", count_not_1)
# Out:
#               person1            person2  similarity
# 0     Evelyn Hartmann         John Smith    1.000000
# 1         Mia Schäfer     Henry Schröder    0.666667
# 2    Olivia Schneider  Alexander Neumann    0.666667
# 3            Jane Doe  Alexander Neumann    0.500000
# 4    Olivia Schneider      Sophia Wagner    0.500000
# ..                ...                ...         ...
# 898     William Meyer   Olivia Schneider    0.000000
# 899     William Meyer      Sophia Wagner    0.000000
# 900     William Meyer      Sophia Wagner    0.000000
# 901     William Meyer      Sophia Wagner    0.000000
# 902     William Meyer      William Meyer    0.000000
#
# [903 rows x 3 columns]
# Anzahl der Ähnlichkeiten mit Wert 1: 1
# Anzahl der Ähnlichkeiten mit Wert ungleich 1: 902

# %% [markdown]
# #### Prozentsatz der Transaktionen unter 300 für jede Person-Personer-Kombination

# %%
from neo4j import GraphDatabase
import pandas as pd

uri = "bolt://localhost:7687"
user = "neo4j"
password = ""  

driver = GraphDatabase.driver(uri, auth=(user, password))

def get_transactions_under_300(tx):
    query = """
    MATCH (p:Person)-[t:TRANSACTION]->(other:Person)
    WHERE t.amount < 300
    RETURN p.name AS personName, other.name AS partnerName, COUNT(t) AS transactionsUnder300
    ORDER BY p.name, other.name
    """
    result = tx.run(query)
    return [{"personName": record["personName"], "partnerName": record["partnerName"], "transactionsUnder300": record["transactionsUnder300"]} for record in result]

def get_total_transactions(tx):
    query = """
    MATCH (p:Person)-[t:TRANSACTION]->(other:Person)
    RETURN p.name AS personName, other.name AS partnerName, COUNT(t) AS totalTransactions
    ORDER BY p.name, other.name
    """
    result = tx.run(query)
    return [{"personName": record["personName"], "partnerName": record["partnerName"], "totalTransactions": record["totalTransactions"]} for record in result]

with driver.session() as session:
    transactions_under_300 = session.read_transaction(get_transactions_under_300)
    total_transactions = session.read_transaction(get_total_transactions)


df_under_300 = pd.DataFrame(transactions_under_300)
df_total = pd.DataFrame(total_transactions)


merged_df = pd.merge(df_under_300, df_total, on=['personName', 'partnerName'])


merged_df['percentageUnder300'] = (merged_df['transactionsUnder300'] / merged_df['totalTransactions']) * 100


print(merged_df[['personName', 'partnerName', 'transactionsUnder300', 'totalTransactions', 'percentageUnder300']])
# Out:
# C:\Users\Noemi\AppData\Local\Temp\ipykernel_11284\3239147195.py:30: DeprecationWarning: read_transaction has been renamed to execute_read
#   transactions_under_300 = session.read_transaction(get_transactions_under_300)
# C:\Users\Noemi\AppData\Local\Temp\ipykernel_11284\3239147195.py:31: DeprecationWarning: read_transaction has been renamed to execute_read
#   total_transactions = session.read_transaction(get_total_transactions)
#      personName    partnerName  transactionsUnder300  totalTransactions  \
# 0     Ava Weber  William Meyer                    11                 12
# 1  James Becker   Liam Schmidt                     9                 10
# 2  James Becker  Oliver Schulz                     9                  9
#
#    percentageUnder300
# 0           91.666667
# 1           90.000000
# 2          100.000000

# %%
analysis_requests = []
for index, row in merged_df.iterrows():
    analysis_request = f"""
    Analyze transactions pattern for {row['personName']} and {row['partnerName']}:
    - Transactions under 300: {row['transactionsUnder300']}
    - Total transactions: {row['totalTransactions']}
    - Percentage under 300: {row['percentageUnder300']:.2f}%
    Does this pattern indicate potential money laundering activities?
    """
    analysis_requests.append(analysis_request.strip())

print(analysis_requests[0])
# Out:
# Analyze transactions pattern for Ava Weber and William Meyer:
#     - Transactions under 300: 11
#     - Total transactions: 12
#     - Percentage under 300: 91.67%
#     Does this pattern indicate potential money laundering activities?

# %%
def run_query(query):
    with driver.session() as session:
        result = session.run(query)
        return [record for record in result]

# Beispielabfrage: Finden Sie alle Personen und ihre Transaktionen
query = """
MATCH (p:Person)-[t:TRANSACTION]->()
WITH p, AVG(t.amount) AS avgAmount
WHERE avgAmount > 10000  // 
RETURN p.name AS personName, avgAmount
ORDER BY avgAmount DESC
"""
results = run_query(query)

for record in results:
    print(record)
# Out:
# <Record personName='Noah Fischer' avgAmount=1671432.3333333335>
# <Record personName='Isabella Hoffmann' avgAmount=852435.8333333334>
# <Record personName='Olivia Schneider' avgAmount=334131.6666666666>
# <Record personName='Mia Schäfer' avgAmount=55816.5>
# <Record personName='Noah Fischer' avgAmount=52930.0>
# <Record personName='Max Mustermann' avgAmount=50000.0>
# <Record personName='John Smith' avgAmount=30000.0>
# <Record personName='Oliver Schulz' avgAmount=21789.0>

# %%
from py2neo import Graph
graph = Graph("bolt://localhost:7687", auth=("neo4j", ""))

jaccard_query = """
CALL gds.nodeSimilarity.stream('myGraphConnections')
YIELD node1, node2, similarity
RETURN gds.util.asNode(node1).name AS node1, gds.util.asNode(node2).name AS node2, similarity
ORDER BY similarity DESC
"""

jaccard_results = graph.run(jaccard_query).data()

for result in jaccard_results:
    print(result)
# Out:
# {'node1': 'Olivia Schneider', 'node2': 'Noah Fischer', 'similarity': 0.5}
# {'node1': 'Noah Fischer', 'node2': 'Olivia Schneider', 'similarity': 0.5}
# {'node1': 'Emma Müller', 'node2': 'Harper Krüger', 'similarity': 0.5}
# {'node1': 'Ava Weber', 'node2': 'Harper Krüger', 'similarity': 0.5}
# {'node1': 'Harper Krüger', 'node2': 'Ava Weber', 'similarity': 0.5}
# {'node1': 'Harper Krüger', 'node2': 'Emma Müller', 'similarity': 0.5}
# {'node1': 'Charlotte Bauer', 'node2': 'Alexander Neumann', 'similarity': 0.4}
# {'node1': 'Alexander Neumann', 'node2': 'Charlotte Bauer', 'similarity': 0.4}
# {'node1': 'Alexander Neumann', 'node2': 'Olivia Schneider', 'similarity': 0.4}
# {'node1': 'Emma Müller', 'node2': 'Harper Krüger', 'similarity': 0.4}
# {'node1': 'William Meyer', 'node2': 'Mia Schäfer', 'similarity': 0.4}
# {'node1': 'Benjamin Koch', 'node2': 'Henry Schröder', 'similarity': 0.4}
# {'node1': 'Charlotte Bauer', 'node2': 'Alexander Neumann', 'similarity': 0.4}
# {'node1': 'Mia Schäfer', 'node2': 'William Meyer', 'similarity': 0.4}
# {'node1': 'Alexander Neumann', 'node2': 'Charlotte Bauer', 'similarity': 0.4}
# {'node1': 'Harper Krüger', 'node2': 'Emma Müller', 'similarity': 0.4}
# {'node1': 'Henry Schröder', 'node2': 'Benjamin Koch', 'similarity': 0.4}
# {'node1': 'Olivia Schneider', 'node2': 'Alexander Neumann', 'similarity': 0.4}
# {'node1': 'Isabella Hoffmann', 'node2': 'Ethan Schwarz', 'similarity': 0.375}
# {'node1': 'Ethan Schwarz', 'node2': 'Isabella Hoffmann', 'similarity': 0.375}
# {'node1': 'Benjamin Koch', 'node2': 'Henry Schröder', 'similarity': 0.3333333333333333}
# {'node1': 'Lucas Zimmermann', 'node2': 'Sophia Wagner', 'similarity': 0.3333333333333333}
# {'node1': 'Lucas Zimmermann', 'node2': 'Mason Braun', 'similarity': 0.3333333333333333}
# {'node1': 'Lucas Zimmermann', 'node2': 'Ava Weber', 'similarity': 0.3333333333333333}
# {'node1': 'Mia Schäfer', 'node2': 'William Meyer', 'similarity': 0.3333333333333333}
# {'node1': 'Mason Braun', 'node2': 'Lucas Zimmermann', 'similarity': 0.3333333333333333}
# {'node1': 'Ethan Schwarz', 'node2': 'Henry Schröder', 'similarity': 0.3333333333333333}
# {'node1': 'Alexander Neumann', 'node2': 'Sophia Wagner', 'similarity': 0.3333333333333333}
# {'node1': 'Alexander Neumann', 'node2': 'Jane Doe', 'similarity': 0.3333333333333333}
# {'node1': 'Henry Schröder', 'node2': 'Ethan Schwarz', 'similarity': 0.3333333333333333}
# {'node1': 'Henry Schröder', 'node2': 'Benjamin Koch', 'similarity': 0.3333333333333333}
# {'node1': 'Evelyn Hartmann', 'node2': 'Sophia Wagner', 'similarity': 0.3333333333333333}
# {'node1': 'Evelyn Hartmann', 'node2': 'John Smith', 'similarity': 0.3333333333333333}
# {'node1': 'Evelyn Hartmann', 'node2': 'Ava Weber', 'similarity': 0.3333333333333333}
# {'node1': 'John Smith', 'node2': 'Evelyn Hartmann', 'similarity': 0.3333333333333333}
# {'node1': 'Harper Krüger', 'node2': 'Ava Weber', 'similarity': 0.3333333333333333}
# {'node1': 'Henry Schröder', 'node2': 'Ethan Schwarz', 'similarity': 0.3333333333333333}
# {'node1': 'Evelyn Hartmann', 'node2': 'Ava Weber', 'similarity': 0.3333333333333333}
# {'node1': 'Jane Doe', 'node2': 'Alexander Neumann', 'similarity': 0.3333333333333333}
# {'node1': 'Liam Schmidt', 'node2': 'Noah Fischer', 'similarity': 0.3333333333333333}
# {'node1': 'Noah Fischer', 'node2': 'Liam Schmidt', 'similarity': 0.3333333333333333}
# {'node1': 'Ava Weber', 'node2': 'Evelyn Hartmann', 'similarity': 0.3333333333333333}
# {'node1': 'Ava Weber', 'node2': 'Lucas Zimmermann', 'similarity': 0.3333333333333333}
# {'node1': 'William Meyer', 'node2': 'Mia Schäfer', 'similarity': 0.3333333333333333}
# {'node1': 'Sophia Wagner', 'node2': 'Alexander Neumann', 'similarity': 0.3333333333333333}
# {'node1': 'Sophia Wagner', 'node2': 'Evelyn Hartmann', 'similarity': 0.3333333333333333}
# {'node1': 'Sophia Wagner', 'node2': 'Lucas Zimmermann', 'similarity': 0.3333333333333333}
# {'node1': 'Ava Weber', 'node2': 'Harper Krüger', 'similarity': 0.3333333333333333}
# {'node1': 'Ava Weber', 'node2': 'Evelyn Hartmann', 'similarity': 0.3333333333333333}
# {'node1': 'Ava Weber', 'node2': 'Lucas Zimmermann', 'similarity': 0.3333333333333333}
# {'node1': 'Lucas Zimmermann', 'node2': 'Mason Braun', 'similarity': 0.3333333333333333}
# {'node1': 'Lucas Zimmermann', 'node2': 'Ava Weber', 'similarity': 0.3333333333333333}
# {'node1': 'Mason Braun', 'node2': 'Lucas Zimmermann', 'similarity': 0.3333333333333333}
# {'node1': 'Ethan Schwarz', 'node2': 'Henry Schröder', 'similarity': 0.3333333333333333}
# {'node1': 'James Becker', 'node2': 'James Becker', 'similarity': 0.3076923076923077}
# {'node1': 'James Becker', 'node2': 'James Becker', 'similarity': 0.3076923076923077}
# {'node1': 'Harper Krüger', 'node2': 'Isabella Hoffmann', 'similarity': 0.2857142857142857}
# {'node1': 'Henry Schröder', 'node2': 'Mia Schäfer', 'similarity': 0.2857142857142857}
# {'node1': 'Evelyn Hartmann', 'node2': 'Isabella Hoffmann', 'similarity': 0.2857142857142857}
# {'node1': 'Olivia Schneider', 'node2': 'Sophia Wagner', 'similarity': 0.2857142857142857}
# {'node1': 'Olivia Schneider', 'node2': 'Noah Fischer', 'similarity': 0.2857142857142857}
# {'node1': 'Noah Fischer', 'node2': 'Benjamin Koch', 'similarity': 0.2857142857142857}
# {'node1': 'Noah Fischer', 'node2': 'Olivia Schneider', 'similarity': 0.2857142857142857}
# {'node1': 'Sophia Wagner', 'node2': 'Charlotte Bauer', 'similarity': 0.2857142857142857}
# {'node1': 'Sophia Wagner', 'node2': 'Olivia Schneider', 'similarity': 0.2857142857142857}
# {'node1': 'Benjamin Koch', 'node2': 'Noah Fischer', 'similarity': 0.2857142857142857}
# {'node1': 'Charlotte Bauer', 'node2': 'Sophia Wagner', 'similarity': 0.2857142857142857}
# {'node1': 'Emma Müller', 'node2': 'Ava Weber', 'similarity': 0.2857142857142857}
# {'node1': 'Ava Weber', 'node2': 'Emma Müller', 'similarity': 0.2857142857142857}
# {'node1': 'Isabella Hoffmann', 'node2': 'Evelyn Hartmann', 'similarity': 0.2857142857142857}
# {'node1': 'Isabella Hoffmann', 'node2': 'Harper Krüger', 'similarity': 0.2857142857142857}
# {'node1': 'Charlotte Bauer', 'node2': 'Mia Schäfer', 'similarity': 0.2857142857142857}
# {'node1': 'Mia Schäfer', 'node2': 'Henry Schröder', 'similarity': 0.2857142857142857}
# {'node1': 'Mia Schäfer', 'node2': 'Ethan Schwarz', 'similarity': 0.2857142857142857}
# {'node1': 'Mia Schäfer', 'node2': 'Charlotte Bauer', 'similarity': 0.2857142857142857}
# {'node1': 'Ethan Schwarz', 'node2': 'Mia Schäfer', 'similarity': 0.2857142857142857}
# {'node1': 'Olivia Schneider', 'node2': 'Sophia Wagner', 'similarity': 0.25}
# {'node1': 'Ava Weber', 'node2': 'Mason Braun', 'similarity': 0.25}
# {'node1': 'Sophia Wagner', 'node2': 'Evelyn Hartmann', 'similarity': 0.25}
# {'node1': 'Sophia Wagner', 'node2': 'Alexander Neumann', 'similarity': 0.25}
# {'node1': 'Sophia Wagner', 'node2': 'Olivia Schneider', 'similarity': 0.25}
# {'node1': 'Isabella Hoffmann', 'node2': 'Ethan Schwarz', 'similarity': 0.25}
# {'node1': 'Oliver Schulz', 'node2': 'Henry Schröder', 'similarity': 0.25}
# {'node1': 'Oliver Schulz', 'node2': 'Ethan Schwarz', 'similarity': 0.25}
# {'node1': 'Charlotte Bauer', 'node2': 'Liam Schmidt', 'similarity': 0.25}
# {'node1': 'Mason Braun', 'node2': 'Ava Weber', 'similarity': 0.25}
# {'node1': 'Ethan Schwarz', 'node2': 'Oliver Schulz', 'similarity': 0.25}
# {'node1': 'Ethan Schwarz', 'node2': 'Isabella Hoffmann', 'similarity': 0.25}
# {'node1': 'Alexander Neumann', 'node2': 'Sophia Wagner', 'similarity': 0.25}
# {'node1': 'Henry Schröder', 'node2': 'Oliver Schulz', 'similarity': 0.25}
# {'node1': 'Evelyn Hartmann', 'node2': 'Sophia Wagner', 'similarity': 0.25}
# {'node1': 'Max Mustermann', 'node2': 'Ethan Schwarz', 'similarity': 0.25}
# {'node1': 'Jane Doe', 'node2': 'Olivia Schneider', 'similarity': 0.25}
# {'node1': 'Emma Müller', 'node2': 'Ava Weber', 'similarity': 0.25}
# {'node1': 'Olivia Schneider', 'node2': 'Jane Doe', 'similarity': 0.25}
# {'node1': 'Ava Weber', 'node2': 'Mason Braun', 'similarity': 0.25}
# {'node1': 'Ava Weber', 'node2': 'Emma Müller', 'similarity': 0.25}
# {'node1': 'Sophia Wagner', 'node2': 'Mason Braun', 'similarity': 0.25}
# {'node1': 'James Becker', 'node2': 'Mia Schäfer', 'similarity': 0.25}
# {'node1': 'Isabella Hoffmann', 'node2': 'Evelyn Hartmann', 'similarity': 0.25}
# {'node1': 'Oliver Schulz', 'node2': 'Henry Schröder', 'similarity': 0.25}
# {'node1': 'Oliver Schulz', 'node2': 'Ethan Schwarz', 'similarity': 0.25}
# {'node1': 'Benjamin Koch', 'node2': 'Mia Schäfer', 'similarity': 0.25}
# {'node1': 'Charlotte Bauer', 'node2': 'Mia Schäfer', 'similarity': 0.25}
# {'node1': 'Mia Schäfer', 'node2': 'Ethan Schwarz', 'similarity': 0.25}
# {'node1': 'Mia Schäfer', 'node2': 'Charlotte Bauer', 'similarity': 0.25}
# {'node1': 'Mia Schäfer', 'node2': 'Benjamin Koch', 'similarity': 0.25}
# {'node1': 'Mia Schäfer', 'node2': 'Henry Schröder', 'similarity': 0.25}
# {'node1': 'Mia Schäfer', 'node2': 'James Becker', 'similarity': 0.25}
# {'node1': 'Mason Braun', 'node2': 'Sophia Wagner', 'similarity': 0.25}
# {'node1': 'Mason Braun', 'node2': 'Ava Weber', 'similarity': 0.25}
# {'node1': 'Ethan Schwarz', 'node2': 'Oliver Schulz', 'similarity': 0.25}
# {'node1': 'Ethan Schwarz', 'node2': 'Mia Schäfer', 'similarity': 0.25}
# {'node1': 'Ethan Schwarz', 'node2': 'Max Mustermann', 'similarity': 0.25}
# {'node1': 'Henry Schröder', 'node2': 'Mia Schäfer', 'similarity': 0.25}
# {'node1': 'Henry Schröder', 'node2': 'Oliver Schulz', 'similarity': 0.25}
# {'node1': 'Evelyn Hartmann', 'node2': 'Isabella Hoffmann', 'similarity': 0.25}
# {'node1': 'Liam Schmidt', 'node2': 'Charlotte Bauer', 'similarity': 0.25}
# {'node1': 'Oliver Schulz', 'node2': 'Mason Braun', 'similarity': 0.2222222222222222}
# {'node1': 'Oliver Schulz', 'node2': 'Sophia Wagner', 'similarity': 0.2222222222222222}
# {'node1': 'Charlotte Bauer', 'node2': 'Liam Schmidt', 'similarity': 0.2222222222222222}
# {'node1': 'Mason Braun', 'node2': 'Oliver Schulz', 'similarity': 0.2222222222222222}
# {'node1': 'Harper Krüger', 'node2': 'Isabella Hoffmann', 'similarity': 0.2222222222222222}
# {'node1': 'Henry Schröder', 'node2': 'Isabella Hoffmann', 'similarity': 0.2222222222222222}
# {'node1': 'Olivia Schneider', 'node2': 'James Becker', 'similarity': 0.2222222222222222}
# {'node1': 'James Becker', 'node2': 'Olivia Schneider', 'similarity': 0.2222222222222222}
# {'node1': 'Oliver Schulz', 'node2': 'Mason Braun', 'similarity': 0.2222222222222222}
# {'node1': 'Mason Braun', 'node2': 'Oliver Schulz', 'similarity': 0.2222222222222222}
# {'node1': 'Liam Schmidt', 'node2': 'Charlotte Bauer', 'similarity': 0.2222222222222222}
# {'node1': 'Sophia Wagner', 'node2': 'Oliver Schulz', 'similarity': 0.2222222222222222}
# {'node1': 'Isabella Hoffmann', 'node2': 'Henry Schröder', 'similarity': 0.2222222222222222}
# {'node1': 'Isabella Hoffmann', 'node2': 'Harper Krüger', 'similarity': 0.2222222222222222}
# {'node1': 'Harper Krüger', 'node2': 'Evelyn Hartmann', 'similarity': 0.2}
# {'node1': 'Harper Krüger', 'node2': 'Lucas Zimmermann', 'similarity': 0.2}
# {'node1': 'Henry Schröder', 'node2': 'William Meyer', 'similarity': 0.2}
# {'node1': 'Evelyn Hartmann', 'node2': 'Harper Krüger', 'similarity': 0.2}
# {'node1': 'Evelyn Hartmann', 'node2': 'Lucas Zimmermann', 'similarity': 0.2}
# {'node1': 'Max Mustermann', 'node2': 'Mason Braun', 'similarity': 0.2}
# {'node1': 'Jane Doe', 'node2': 'Sophia Wagner', 'similarity': 0.2}
# {'node1': 'William Meyer', 'node2': 'Ethan Schwarz', 'similarity': 0.2}
# {'node1': 'William Meyer', 'node2': 'Henry Schröder', 'similarity': 0.2}
# {'node1': 'William Meyer', 'node2': 'Charlotte Bauer', 'similarity': 0.2}
# {'node1': 'Sophia Wagner', 'node2': 'John Smith', 'similarity': 0.2}
# {'node1': 'Sophia Wagner', 'node2': 'Isabella Hoffmann', 'similarity': 0.2}
# {'node1': 'Sophia Wagner', 'node2': 'Jane Doe', 'similarity': 0.2}
# {'node1': 'Isabella Hoffmann', 'node2': 'Sophia Wagner', 'similarity': 0.2}
# {'node1': 'Oliver Schulz', 'node2': 'Liam Schmidt', 'similarity': 0.2}
# {'node1': 'Oliver Schulz', 'node2': 'Oliver Schulz', 'similarity': 0.2}
# {'node1': 'Charlotte Bauer', 'node2': 'William Meyer', 'similarity': 0.2}
# {'node1': 'Lucas Zimmermann', 'node2': 'Evelyn Hartmann', 'similarity': 0.2}
# {'node1': 'Mason Braun', 'node2': 'Max Mustermann', 'similarity': 0.2}
# {'node1': 'Ethan Schwarz', 'node2': 'William Meyer', 'similarity': 0.2}
# {'node1': 'Henry Schröder', 'node2': 'William Meyer', 'similarity': 0.2}
# {'node1': 'Evelyn Hartmann', 'node2': 'Lucas Zimmermann', 'similarity': 0.2}
# {'node1': 'Emma Müller', 'node2': 'James Becker', 'similarity': 0.2}
# {'node1': 'Emma Müller', 'node2': 'William Meyer', 'similarity': 0.2}
# {'node1': 'Liam Schmidt', 'node2': 'Oliver Schulz', 'similarity': 0.2}
# {'node1': 'Liam Schmidt', 'node2': 'Oliver Schulz', 'similarity': 0.2}
# {'node1': 'John Smith', 'node2': 'Sophia Wagner', 'similarity': 0.2}
# {'node1': 'Olivia Schneider', 'node2': 'Alexander Neumann', 'similarity': 0.2}
# {'node1': 'Noah Fischer', 'node2': 'Benjamin Koch', 'similarity': 0.2}
# {'node1': 'William Meyer', 'node2': 'Ethan Schwarz', 'similarity': 0.2}
# {'node1': 'William Meyer', 'node2': 'Emma Müller', 'similarity': 0.2}
# {'node1': 'William Meyer', 'node2': 'Henry Schröder', 'similarity': 0.2}
# {'node1': 'William Meyer', 'node2': 'Charlotte Bauer', 'similarity': 0.2}
# {'node1': 'James Becker', 'node2': 'Emma Müller', 'similarity': 0.2}
# {'node1': 'Oliver Schulz', 'node2': 'Liam Schmidt', 'similarity': 0.2}
# {'node1': 'Oliver Schulz', 'node2': 'Oliver Schulz', 'similarity': 0.2}
# {'node1': 'Benjamin Koch', 'node2': 'Noah Fischer', 'similarity': 0.2}
# {'node1': 'Charlotte Bauer', 'node2': 'William Meyer', 'similarity': 0.2}
# {'node1': 'Lucas Zimmermann', 'node2': 'Evelyn Hartmann', 'similarity': 0.2}
# {'node1': 'Lucas Zimmermann', 'node2': 'Harper Krüger', 'similarity': 0.2}
# {'node1': 'Ethan Schwarz', 'node2': 'William Meyer', 'similarity': 0.2}
# {'node1': 'Alexander Neumann', 'node2': 'Olivia Schneider', 'similarity': 0.2}
# {'node1': 'James Becker', 'node2': 'Mason Braun', 'similarity': 0.18181818181818182}
# {'node1': 'James Becker', 'node2': 'Mia Schäfer', 'similarity': 0.18181818181818182}
# {'node1': 'Oliver Schulz', 'node2': 'Liam Schmidt', 'similarity': 0.18181818181818182}
# {'node1': 'Mia Schäfer', 'node2': 'James Becker', 'similarity': 0.18181818181818182}
# {'node1': 'Mason Braun', 'node2': 'James Becker', 'similarity': 0.18181818181818182}
# {'node1': 'Liam Schmidt', 'node2': 'Mia Schäfer', 'similarity': 0.18181818181818182}
# {'node1': 'Liam Schmidt', 'node2': 'Oliver Schulz', 'similarity': 0.18181818181818182}
# {'node1': 'Liam Schmidt', 'node2': 'Liam Schmidt', 'similarity': 0.18181818181818182}
# {'node1': 'Liam Schmidt', 'node2': 'Oliver Schulz', 'similarity': 0.18181818181818182}
# {'node1': 'Olivia Schneider', 'node2': 'James Becker', 'similarity': 0.18181818181818182}
# {'node1': 'James Becker', 'node2': 'Olivia Schneider', 'similarity': 0.18181818181818182}
# {'node1': 'Isabella Hoffmann', 'node2': 'Oliver Schulz', 'similarity': 0.18181818181818182}
# {'node1': 'Oliver Schulz', 'node2': 'Isabella Hoffmann', 'similarity': 0.18181818181818182}
# {'node1': 'Oliver Schulz', 'node2': 'Liam Schmidt', 'similarity': 0.18181818181818182}
# {'node1': 'Mia Schäfer', 'node2': 'Liam Schmidt', 'similarity': 0.18181818181818182}
# {'node1': 'Liam Schmidt', 'node2': 'Liam Schmidt', 'similarity': 0.18181818181818182}
# {'node1': 'Oliver Schulz', 'node2': 'Jane Doe', 'similarity': 0.16666666666666666}
# {'node1': 'Oliver Schulz', 'node2': 'Max Mustermann', 'similarity': 0.16666666666666666}
# {'node1': 'Charlotte Bauer', 'node2': 'Lucas Zimmermann', 'similarity': 0.16666666666666666}
# {'node1': 'Lucas Zimmermann', 'node2': 'Harper Krüger', 'similarity': 0.16666666666666666}
# {'node1': 'Lucas Zimmermann', 'node2': 'Charlotte Bauer', 'similarity': 0.16666666666666666}
# {'node1': 'Mason Braun', 'node2': 'James Becker', 'similarity': 0.16666666666666666}
# {'node1': 'Harper Krüger', 'node2': 'Evelyn Hartmann', 'similarity': 0.16666666666666666}
# {'node1': 'Harper Krüger', 'node2': 'Lucas Zimmermann', 'similarity': 0.16666666666666666}
# {'node1': 'Evelyn Hartmann', 'node2': 'Harper Krüger', 'similarity': 0.16666666666666666}
# {'node1': 'Emma Müller', 'node2': 'Lucas Zimmermann', 'similarity': 0.16666666666666666}
# {'node1': 'Emma Müller', 'node2': 'Benjamin Koch', 'similarity': 0.16666666666666666}
# {'node1': 'Emma Müller', 'node2': 'Noah Fischer', 'similarity': 0.16666666666666666}
# {'node1': 'Noah Fischer', 'node2': 'Emma Müller', 'similarity': 0.16666666666666666}
# {'node1': 'Noah Fischer', 'node2': 'Henry Schröder', 'similarity': 0.16666666666666666}
# {'node1': 'Benjamin Koch', 'node2': 'Emma Müller', 'similarity': 0.16666666666666666}
# {'node1': 'Charlotte Bauer', 'node2': 'Lucas Zimmermann', 'similarity': 0.16666666666666666}
# {'node1': 'Lucas Zimmermann', 'node2': 'Emma Müller', 'similarity': 0.16666666666666666}
# {'node1': 'Lucas Zimmermann', 'node2': 'Charlotte Bauer', 'similarity': 0.16666666666666666}
# {'node1': 'Henry Schröder', 'node2': 'Noah Fischer', 'similarity': 0.16666666666666666}
# {'node1': 'Max Mustermann', 'node2': 'Oliver Schulz', 'similarity': 0.16666666666666666}
# {'node1': 'Jane Doe', 'node2': 'Oliver Schulz', 'similarity': 0.16666666666666666}
# {'node1': 'Emma Müller', 'node2': 'James Becker', 'similarity': 0.16666666666666666}
# {'node1': 'Emma Müller', 'node2': 'William Meyer', 'similarity': 0.16666666666666666}
# {'node1': 'Noah Fischer', 'node2': 'James Becker', 'similarity': 0.16666666666666666}
# {'node1': 'William Meyer', 'node2': 'Emma Müller', 'similarity': 0.16666666666666666}
# {'node1': 'James Becker', 'node2': 'Sophia Wagner', 'similarity': 0.16666666666666666}
# {'node1': 'James Becker', 'node2': 'Mason Braun', 'similarity': 0.16666666666666666}
# {'node1': 'James Becker', 'node2': 'Noah Fischer', 'similarity': 0.16666666666666666}
# {'node1': 'James Becker', 'node2': 'Emma Müller', 'similarity': 0.16666666666666666}
# {'node1': 'Henry Schröder', 'node2': 'Emma Müller', 'similarity': 0.14285714285714285}
# {'node1': 'Evelyn Hartmann', 'node2': 'Mason Braun', 'similarity': 0.14285714285714285}
# {'node1': 'Max Mustermann', 'node2': 'Isabella Hoffmann', 'similarity': 0.14285714285714285}
# {'node1': 'Emma Müller', 'node2': 'Lucas Zimmermann', 'similarity': 0.14285714285714285}
# {'node1': 'Liam Schmidt', 'node2': 'James Becker', 'similarity': 0.14285714285714285}
# {'node1': 'Olivia Schneider', 'node2': 'Charlotte Bauer', 'similarity': 0.14285714285714285}
# {'node1': 'Noah Fischer', 'node2': 'Alexander Neumann', 'similarity': 0.14285714285714285}
# {'node1': 'James Becker', 'node2': 'Liam Schmidt', 'similarity': 0.14285714285714285}
# {'node1': 'Isabella Hoffmann', 'node2': 'John Smith', 'similarity': 0.14285714285714285}
# {'node1': 'Isabella Hoffmann', 'node2': 'Max Mustermann', 'similarity': 0.14285714285714285}
# {'node1': 'Benjamin Koch', 'node2': 'Harper Krüger', 'similarity': 0.14285714285714285}
# {'node1': 'Charlotte Bauer', 'node2': 'Olivia Schneider', 'similarity': 0.14285714285714285}
# {'node1': 'Lucas Zimmermann', 'node2': 'Emma Müller', 'similarity': 0.14285714285714285}
# {'node1': 'Mason Braun', 'node2': 'Evelyn Hartmann', 'similarity': 0.14285714285714285}
# {'node1': 'Alexander Neumann', 'node2': 'Noah Fischer', 'similarity': 0.14285714285714285}
# {'node1': 'Harper Krüger', 'node2': 'Henry Schröder', 'similarity': 0.14285714285714285}
# {'node1': 'Harper Krüger', 'node2': 'Benjamin Koch', 'similarity': 0.14285714285714285}
# {'node1': 'Henry Schröder', 'node2': 'Harper Krüger', 'similarity': 0.14285714285714285}
# {'node1': 'Evelyn Hartmann', 'node2': 'Mason Braun', 'similarity': 0.14285714285714285}
# {'node1': 'Emma Müller', 'node2': 'Henry Schröder', 'similarity': 0.14285714285714285}
# {'node1': 'Emma Müller', 'node2': 'Charlotte Bauer', 'similarity': 0.14285714285714285}
# {'node1': 'John Smith', 'node2': 'Isabella Hoffmann', 'similarity': 0.14285714285714285}
# {'node1': 'Olivia Schneider', 'node2': 'Mason Braun', 'similarity': 0.14285714285714285}
# {'node1': 'Noah Fischer', 'node2': 'Mason Braun', 'similarity': 0.14285714285714285}
# {'node1': 'Noah Fischer', 'node2': 'Ava Weber', 'similarity': 0.14285714285714285}
# {'node1': 'Ava Weber', 'node2': 'Benjamin Koch', 'similarity': 0.14285714285714285}
# {'node1': 'Ava Weber', 'node2': 'Noah Fischer', 'similarity': 0.14285714285714285}
# {'node1': 'William Meyer', 'node2': 'Isabella Hoffmann', 'similarity': 0.14285714285714285}
# {'node1': 'Sophia Wagner', 'node2': 'Oliver Schulz', 'similarity': 0.14285714285714285}
# {'node1': 'Sophia Wagner', 'node2': 'Isabella Hoffmann', 'similarity': 0.14285714285714285}
# {'node1': 'Isabella Hoffmann', 'node2': 'Sophia Wagner', 'similarity': 0.14285714285714285}
# {'node1': 'Isabella Hoffmann', 'node2': 'William Meyer', 'similarity': 0.14285714285714285}
# {'node1': 'Oliver Schulz', 'node2': 'Sophia Wagner', 'similarity': 0.14285714285714285}
# {'node1': 'Benjamin Koch', 'node2': 'Mia Schäfer', 'similarity': 0.14285714285714285}
# {'node1': 'Benjamin Koch', 'node2': 'Ava Weber', 'similarity': 0.14285714285714285}
# {'node1': 'Charlotte Bauer', 'node2': 'Emma Müller', 'similarity': 0.14285714285714285}
# {'node1': 'Lucas Zimmermann', 'node2': 'Mia Schäfer', 'similarity': 0.14285714285714285}
# {'node1': 'Mia Schäfer', 'node2': 'Lucas Zimmermann', 'similarity': 0.14285714285714285}
# {'node1': 'Mia Schäfer', 'node2': 'Benjamin Koch', 'similarity': 0.14285714285714285}
# {'node1': 'Mason Braun', 'node2': 'Evelyn Hartmann', 'similarity': 0.14285714285714285}
# {'node1': 'Mason Braun', 'node2': 'Noah Fischer', 'similarity': 0.14285714285714285}
# {'node1': 'Mason Braun', 'node2': 'Olivia Schneider', 'similarity': 0.14285714285714285}
# {'node1': 'Olivia Schneider', 'node2': 'Liam Schmidt', 'similarity': 0.125}
# {'node1': 'Olivia Schneider', 'node2': 'Oliver Schulz', 'similarity': 0.125}
# {'node1': 'Noah Fischer', 'node2': 'Liam Schmidt', 'similarity': 0.125}
# {'node1': 'Noah Fischer', 'node2': 'Oliver Schulz', 'similarity': 0.125}
# {'node1': 'Ava Weber', 'node2': 'Henry Schröder', 'similarity': 0.125}
# {'node1': 'James Becker', 'node2': 'Jane Doe', 'similarity': 0.125}
# {'node1': 'Isabella Hoffmann', 'node2': 'Alexander Neumann', 'similarity': 0.125}
# {'node1': 'Oliver Schulz', 'node2': 'Noah Fischer', 'similarity': 0.125}
# {'node1': 'Oliver Schulz', 'node2': 'Alexander Neumann', 'similarity': 0.125}
# {'node1': 'Oliver Schulz', 'node2': 'Benjamin Koch', 'similarity': 0.125}
# {'node1': 'Benjamin Koch', 'node2': 'Liam Schmidt', 'similarity': 0.125}
# {'node1': 'Benjamin Koch', 'node2': 'Oliver Schulz', 'similarity': 0.125}
# {'node1': 'Charlotte Bauer', 'node2': 'Mason Braun', 'similarity': 0.125}
# {'node1': 'Lucas Zimmermann', 'node2': 'Liam Schmidt', 'similarity': 0.125}
# {'node1': 'Lucas Zimmermann', 'node2': 'Oliver Schulz', 'similarity': 0.125}
# {'node1': 'Lucas Zimmermann', 'node2': 'Oliver Schulz', 'similarity': 0.125}
# {'node1': 'Mia Schäfer', 'node2': 'Emma Müller', 'similarity': 0.125}
# {'node1': 'Mason Braun', 'node2': 'Ethan Schwarz', 'similarity': 0.125}
# {'node1': 'Mason Braun', 'node2': 'Charlotte Bauer', 'similarity': 0.125}
# {'node1': 'Ethan Schwarz', 'node2': 'Mason Braun', 'similarity': 0.125}
# {'node1': 'Alexander Neumann', 'node2': 'Liam Schmidt', 'similarity': 0.125}
# {'node1': 'Alexander Neumann', 'node2': 'Oliver Schulz', 'similarity': 0.125}
# {'node1': 'Alexander Neumann', 'node2': 'Isabella Hoffmann', 'similarity': 0.125}
# {'node1': 'Harper Krüger', 'node2': 'Liam Schmidt', 'similarity': 0.125}
# {'node1': 'Henry Schröder', 'node2': 'Ava Weber', 'similarity': 0.125}
# {'node1': 'Jane Doe', 'node2': 'James Becker', 'similarity': 0.125}
# {'node1': 'Emma Müller', 'node2': 'Henry Schröder', 'similarity': 0.125}
# {'node1': 'Emma Müller', 'node2': 'Charlotte Bauer', 'similarity': 0.125}
# {'node1': 'Emma Müller', 'node2': 'Benjamin Koch', 'similarity': 0.125}
# {'node1': 'Olivia Schneider', 'node2': 'Mason Braun', 'similarity': 0.125}
# {'node1': 'Noah Fischer', 'node2': 'Henry Schröder', 'similarity': 0.125}
# {'node1': 'Noah Fischer', 'node2': 'Harper Krüger', 'similarity': 0.125}
# {'node1': 'Noah Fischer', 'node2': 'Charlotte Bauer', 'similarity': 0.125}
# {'node1': 'Ava Weber', 'node2': 'Henry Schröder', 'similarity': 0.125}
# {'node1': 'Ava Weber', 'node2': 'Benjamin Koch', 'similarity': 0.125}
# {'node1': 'William Meyer', 'node2': 'Isabella Hoffmann', 'similarity': 0.125}
# {'node1': 'Isabella Hoffmann', 'node2': 'William Meyer', 'similarity': 0.125}
# {'node1': 'Benjamin Koch', 'node2': 'Ava Weber', 'similarity': 0.125}
# {'node1': 'Benjamin Koch', 'node2': 'Emma Müller', 'similarity': 0.125}
# {'node1': 'Charlotte Bauer', 'node2': 'Noah Fischer', 'similarity': 0.125}
# {'node1': 'Charlotte Bauer', 'node2': 'Mason Braun', 'similarity': 0.125}
# {'node1': 'Charlotte Bauer', 'node2': 'Emma Müller', 'similarity': 0.125}
# {'node1': 'Lucas Zimmermann', 'node2': 'Oliver Schulz', 'similarity': 0.125}
# {'node1': 'Lucas Zimmermann', 'node2': 'Mia Schäfer', 'similarity': 0.125}
# {'node1': 'Lucas Zimmermann', 'node2': 'Oliver Schulz', 'similarity': 0.125}
# {'node1': 'Mia Schäfer', 'node2': 'Lucas Zimmermann', 'similarity': 0.125}
# {'node1': 'Mason Braun', 'node2': 'Charlotte Bauer', 'similarity': 0.125}
# {'node1': 'Mason Braun', 'node2': 'Ethan Schwarz', 'similarity': 0.125}
# {'node1': 'Mason Braun', 'node2': 'Olivia Schneider', 'similarity': 0.125}
# {'node1': 'Ethan Schwarz', 'node2': 'Mason Braun', 'similarity': 0.125}
# {'node1': 'Alexander Neumann', 'node2': 'Oliver Schulz', 'similarity': 0.125}
# {'node1': 'Harper Krüger', 'node2': 'Noah Fischer', 'similarity': 0.125}
# {'node1': 'Henry Schröder', 'node2': 'Ava Weber', 'similarity': 0.125}
# {'node1': 'Henry Schröder', 'node2': 'Noah Fischer', 'similarity': 0.125}
# {'node1': 'Henry Schröder', 'node2': 'Emma Müller', 'similarity': 0.125}
# {'node1': 'Emma Müller', 'node2': 'Mia Schäfer', 'similarity': 0.125}
# {'node1': 'Liam Schmidt', 'node2': 'Noah Fischer', 'similarity': 0.125}
# {'node1': 'Liam Schmidt', 'node2': 'Lucas Zimmermann', 'similarity': 0.125}
# {'node1': 'Liam Schmidt', 'node2': 'Harper Krüger', 'similarity': 0.125}
# {'node1': 'Liam Schmidt', 'node2': 'Alexander Neumann', 'similarity': 0.125}
# {'node1': 'Liam Schmidt', 'node2': 'Benjamin Koch', 'similarity': 0.125}
# {'node1': 'Liam Schmidt', 'node2': 'Olivia Schneider', 'similarity': 0.125}
# {'node1': 'Benjamin Koch', 'node2': 'Oliver Schulz', 'similarity': 0.1111111111111111}
# {'node1': 'Alexander Neumann', 'node2': 'Isabella Hoffmann', 'similarity': 0.1111111111111111}
# {'node1': 'Alexander Neumann', 'node2': 'Liam Schmidt', 'similarity': 0.1111111111111111}
# {'node1': 'Harper Krüger', 'node2': 'Oliver Schulz', 'similarity': 0.1111111111111111}
# {'node1': 'William Meyer', 'node2': 'James Becker', 'similarity': 0.1111111111111111}
# {'node1': 'Sophia Wagner', 'node2': 'James Becker', 'similarity': 0.1111111111111111}
# {'node1': 'James Becker', 'node2': 'Sophia Wagner', 'similarity': 0.1111111111111111}
# {'node1': 'James Becker', 'node2': 'William Meyer', 'similarity': 0.1111111111111111}
# {'node1': 'Isabella Hoffmann', 'node2': 'Henry Schröder', 'similarity': 0.1111111111111111}
# {'node1': 'Isabella Hoffmann', 'node2': 'Emma Müller', 'similarity': 0.1111111111111111}
# {'node1': 'Isabella Hoffmann', 'node2': 'Charlotte Bauer', 'similarity': 0.1111111111111111}
# {'node1': 'Charlotte Bauer', 'node2': 'Oliver Schulz', 'similarity': 0.1111111111111111}
# {'node1': 'Charlotte Bauer', 'node2': 'Oliver Schulz', 'similarity': 0.1111111111111111}
# {'node1': 'Charlotte Bauer', 'node2': 'Isabella Hoffmann', 'similarity': 0.1111111111111111}
# {'node1': 'Mia Schäfer', 'node2': 'Mason Braun', 'similarity': 0.1111111111111111}
# {'node1': 'Mason Braun', 'node2': 'Mia Schäfer', 'similarity': 0.1111111111111111}
# {'node1': 'Henry Schröder', 'node2': 'Isabella Hoffmann', 'similarity': 0.1111111111111111}
# {'node1': 'Jane Doe', 'node2': 'James Becker', 'similarity': 0.1111111111111111}
# {'node1': 'Emma Müller', 'node2': 'Noah Fischer', 'similarity': 0.1111111111111111}
# {'node1': 'Liam Schmidt', 'node2': 'Lucas Zimmermann', 'similarity': 0.1111111111111111}
# {'node1': 'Liam Schmidt', 'node2': 'Alexander Neumann', 'similarity': 0.1111111111111111}
# {'node1': 'Liam Schmidt', 'node2': 'Lucas Zimmermann', 'similarity': 0.1111111111111111}
# {'node1': 'Olivia Schneider', 'node2': 'Oliver Schulz', 'similarity': 0.1111111111111111}
# {'node1': 'Noah Fischer', 'node2': 'Ava Weber', 'similarity': 0.1111111111111111}
# {'node1': 'Noah Fischer', 'node2': 'Mason Braun', 'similarity': 0.1111111111111111}
# {'node1': 'Ava Weber', 'node2': 'Sophia Wagner', 'similarity': 0.1111111111111111}
# {'node1': 'Ava Weber', 'node2': 'Noah Fischer', 'similarity': 0.1111111111111111}
# {'node1': 'James Becker', 'node2': 'Jane Doe', 'similarity': 0.1111111111111111}
# {'node1': 'Isabella Hoffmann', 'node2': 'Alexander Neumann', 'similarity': 0.1111111111111111}
# {'node1': 'Alexander Neumann', 'node2': 'James Becker', 'similarity': 0.1}
# {'node1': 'Harper Krüger', 'node2': 'James Becker', 'similarity': 0.1}
# {'node1': 'Evelyn Hartmann', 'node2': 'James Becker', 'similarity': 0.1}
# {'node1': 'Emma Müller', 'node2': 'Mia Schäfer', 'similarity': 0.1}
# {'node1': 'Olivia Schneider', 'node2': 'Isabella Hoffmann', 'similarity': 0.1}
# {'node1': 'Olivia Schneider', 'node2': 'Liam Schmidt', 'similarity': 0.1}
# {'node1': 'Ava Weber', 'node2': 'Oliver Schulz', 'similarity': 0.1}
# {'node1': 'William Meyer', 'node2': 'James Becker', 'similarity': 0.1}
# {'node1': 'James Becker', 'node2': 'William Meyer', 'similarity': 0.1}
# {'node1': 'Benjamin Koch', 'node2': 'Liam Schmidt', 'similarity': 0.1}
# {'node1': 'Mia Schäfer', 'node2': 'Sophia Wagner', 'similarity': 0.1}
# {'node1': 'Mia Schäfer', 'node2': 'Mason Braun', 'similarity': 0.1}
# {'node1': 'Alexander Neumann', 'node2': 'James Becker', 'similarity': 0.1}
# {'node1': 'Harper Krüger', 'node2': 'Liam Schmidt', 'similarity': 0.1}
# {'node1': 'Noah Fischer', 'node2': 'James Becker', 'similarity': 0.1}
# {'node1': 'Ava Weber', 'node2': 'Oliver Schulz', 'similarity': 0.1}
# {'node1': 'Ava Weber', 'node2': 'Isabella Hoffmann', 'similarity': 0.1}
# {'node1': 'Sophia Wagner', 'node2': 'James Becker', 'similarity': 0.1}
# {'node1': 'James Becker', 'node2': 'Alexander Neumann', 'similarity': 0.1}
# {'node1': 'James Becker', 'node2': 'Lucas Zimmermann', 'similarity': 0.1}
# {'node1': 'Isabella Hoffmann', 'node2': 'Mason Braun', 'similarity': 0.1}
# {'node1': 'Mia Schäfer', 'node2': 'Oliver Schulz', 'similarity': 0.1}
# {'node1': 'Olivia Schneider', 'node2': 'James Becker', 'similarity': 0.09090909090909091}
# {'node1': 'Ethan Schwarz', 'node2': 'James Becker', 'similarity': 0.09090909090909091}
# {'node1': 'Alexander Neumann', 'node2': 'James Becker', 'similarity': 0.09090909090909091}
# {'node1': 'Evelyn Hartmann', 'node2': 'James Becker', 'similarity': 0.09090909090909091}
# {'node1': 'Alexander Neumann', 'node2': 'James Becker', 'similarity': 0.09090909090909091}
# {'node1': 'Harper Krüger', 'node2': 'James Becker', 'similarity': 0.09090909090909091}
# {'node1': 'Benjamin Koch', 'node2': 'James Becker', 'similarity': 0.08333333333333333}
# {'node1': 'Ethan Schwarz', 'node2': 'James Becker', 'similarity': 0.08333333333333333}

# %% [markdown]
# Ouput Deutung: <br>
# Similarity: Der Wert liegt zwischen 0 und 1, wobei 1 eine maximale Ähnlichkeit darstellt <br>
#
# Zwischen 'Olivia Schneider' und 'Noah Fischer' beträgt die Ähnlichkeit 0.5. Das bedeutet, dass die Nachbarschaften dieser beiden Knoten zur Hälfte ähnlich sind.
#
# Zwischen 'Emma Müller' und 'Harper Krüger' beträgt die Ähnlichkeit ebenfalls 0.5. Das bedeutet, dass die Nachbarschaften dieser beiden Knoten zur Hälfte ähnlich sind.
#
# Zwischen 'Charlotte Bauer' und 'Alexander Neumann' beträgt die Ähnlichkeit 0.4. Das bedeutet, dass die Nachbarschaften dieser beiden Knoten zu 40% ähnlich sind.

# %% [markdown]
# ### Selbsterstelltes Ähnlichkeitsmuster
# Prozentsatz der Transaktionen unter 300 für jede Person-Person-Kombination

# %%
from neo4j import GraphDatabase
import pandas as pd
import openai

class Neo4jConnection:
    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))
        
    def close(self):
        self.driver.close()

    def run_query(self, query):
        with self.driver.session() as session:
            result = session.run(query)
            return [record.data() for record in result]

class OpenAIWrapper:
    def __init__(self, api_key):
        self.api_key = api_key

    def generate_chat_response(self, prompt):
        openai.api_key = self.api_key
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[{"role": "system", "content": "Analyze the following transaction patterns for potential money laundering:"},
                      {"role": "user", "content": prompt}]
        )
        return response.choices[0].message['content']

def analyze_transactions(uri, user, password, api_key, person_name=None):
    neo4j_conn = Neo4jConnection(uri, user, password)
    person_filter = f"WHERE p.name = '{person_name}'" if person_name else ""
    query_transactions_under_300 = f"""
        MATCH (p:Person)-[t:TRANSACTION]->(other:Person)
        {person_filter}
        AND t.amount < 300
        RETURN p.name AS personName, other.name AS partnerName, COUNT(t) AS transactionsUnder300
        ORDER BY p.name, other.name
    """
    query_total_transactions = f"""
        MATCH (p:Person)-[t:TRANSACTION]->(other:Person)
        {person_filter}
        RETURN p.name AS personName, other.name AS partnerName, COUNT(t) AS totalTransactions
        ORDER BY p.name, other.name
    """
    transactions_under_300 = neo4j_conn.run_query(query_transactions_under_300)
    total_transactions = neo4j_conn.run_query(query_total_transactions)

    df_under_300 = pd.DataFrame(transactions_under_300)
    df_total = pd.DataFrame(total_transactions)

    merged_df = pd.merge(df_under_300, df_total, on=['personName', 'partnerName'])
    filtered_df = merged_df[merged_df['transactionsUnder300'] >= 6]
    filtered_df['percentageUnder300'] = (filtered_df['transactionsUnder300'] / filtered_df['totalTransactions']) * 100

    openai_wrapper = OpenAIWrapper(api_key)
    insights = []

    for index, row in filtered_df.iterrows():
        analysis_request = f"""
        Analyze transactions pattern for {row['personName']} and {row['partnerName']}:
        - Transactions under 300: {row['transactionsUnder300']}
        - Total transactions: {row['totalTransactions']}
        - Percentage under 300: {row['percentageUnder300']:.2f}%
        Does this pattern indicate potential money laundering activities?
        """
        response = openai_wrapper.generate_chat_response(analysis_request)
        insights.append(response)

    neo4j_conn.close()
    return insights

# Connection GPT und Neo4j
uri = "bolt://localhost:7687"
user = "neo4j"
password = ""
api_key = ''
person_name = "Ava Weber"

results = analyze_transactions(uri, user, password, api_key, person_name)
for result in results:
    print(result)
